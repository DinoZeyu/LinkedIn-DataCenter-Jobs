# %%
import pandas as pd
import os
import requests
from bs4 import BeautifulSoup
from time import sleep

# %%
df = pd.read_csv('data_center_jobs.csv')

# %%
header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# %%
def extract_information_from_html(html):
    """
    Extract key job info from a LinkedIn job HTML page:
    - Seniority level
    - Employment type
    - Job function
    - Industries
    - Publish time
    - Num applicants
    """

    results = {
        "Seniority level": "",
        "Employment type": "",
        "Job function": "",
        "Industries": "",
        "publish_time": "",
        "num_applicants": ""
    }

    soup = BeautifulSoup(html, 'html.parser')

    # --- Publish time & applicants ---
    company = soup.find('h4', class_='top-card-layout__second-subline')
    if company:
        spans = company.find_all('span')
        if len(spans) >= 3:
            results['publish_time'] = spans[2].get_text(strip=True)
        if len(spans) >= 4:
            results['num_applicants'] = spans[3].get_text(strip=True)

    # --- Job description (structured criteria) ---
    description = soup.find('section', class_='description')
    if description:
        job_criteria = description.find('ul', class_='description__job-criteria-list')
        if job_criteria:
            criteria = job_criteria.find_all('li')
            for criterion in criteria:
                key = criterion.find('h3')
                value = criterion.find('span')
                if key and value:
                    key_text = key.get_text(strip=True)
                    val_text = value.get_text(strip=True)
                    if key_text in results:  # only keep the 4 description-related ones
                        results[key_text] = val_text

    return results

# %%
def extract_job_info_from_urls(df, url_col="job_url", sleep_between=1.5, max_retries=3):
    extracted_data = []

    for i, url in enumerate(df[url_col]):
        html = None
        for attempt in range(max_retries):
            try:
                response = requests.get(url, headers=header, timeout=15)
                if response.status_code == 200:
                    html = response.text
                    break
                else:
                    print(f"{response.status_code} @ row {i}")
            except requests.RequestException as e:
                print(f"{e} @ row {i} (attempt {attempt+1})")
            sleep(sleep_between)  # wait before retry

        if html:
            info = extract_information_from_html(html)
            extracted_data.append(info)
        else:
            extracted_data.append({k: "" for k in [
                "Seniority level", "Employment type", "Job function", 
                "Industries", "publish_time", "num_applicants"
            ]})

        sleep(sleep_between)

    info_df = pd.DataFrame(extracted_data)
    return pd.concat([df.reset_index(drop=True), info_df], axis=1)

# %%
df_final = extract_job_info_from_urls(df)
df_final
# Out:
# 404 @ row 47
# 404 @ row 47
# 404 @ row 47
# Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan? @ row 50 (attempt 1)
# Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan? @ row 50 (attempt 2)
# Invalid URL 'nan': No scheme supplied. Perhaps you meant https://nan? @ row 50 (attempt 3)
# 404 @ row 707
# 404 @ row 707
# 404 @ row 707
# 404 @ row 720
# 404 @ row 720
# 404 @ row 720
# 404 @ row 770
# 404 @ row 770
# 404 @ row 770
# 404 @ row 1383
# 404 @ row 1383
# 404 @ row 1383
# 404 @ row 1458
# 404 @ row 1458
# 404 @ row 1458
# 404 @ row 1461
# 404 @ row 1461
# 404 @ row 1461
# 404 @ row 1528
# 404 @ row 1528
# 404 @ row 1528
# 404 @ row 1761
# 404 @ row 1761
# 404 @ row 1761
# 404 @ row 1836
# 404 @ row 1836
# 404 @ row 8077
# 404 @ row 8077
# 404 @ row 8077
# 404 @ row 8095
# 404 @ row 8095
# 404 @ row 8095
# 404 @ row 8097
# 404 @ row 8097
# 404 @ row 8097
# 404 @ row 8143
# 404 @ row 8143
# 404 @ row 8143
# 404 @ row 8150
# 404 @ row 8150
# 404 @ row 8150
# 404 @ row 8559
# 404 @ row 8559
# 404 @ row 8559
# 404 @ row 8625
# 404 @ row 8625
# 404 @ row 8625
# 404 @ row 8785
# 404 @ row 8785
# 404 @ row 8785
# 404 @ row 9226
# 404 @ row 9226
# 404 @ row 9226
# 404 @ row 10018
# 404 @ row 10018
# 404 @ row 10018
# 404 @ row 10161
# 404 @ row 10161
# 404 @ row 10161
# 404 @ row 10225
# 404 @ row 10225
# 404 @ row 10225
# 404 @ row 10495
# 404 @ row 10495
# 404 @ row 10495
# 404 @ row 10769
# 404 @ row 10769
# 404 @ row 10769
# 404 @ row 10840
# 404 @ row 10840
# 404 @ row 10840
#       state                                         source_url        job_id  \
# 0        HI  https://www.linkedin.com/jobs/search/?sortBy=R...  4.304561e+09
# 1        HI  https://www.linkedin.com/jobs/search/?sortBy=R...  4.305162e+09
# 2        HI  https://www.linkedin.com/jobs/search/?sortBy=R...  4.304447e+09
# 3        HI  https://www.linkedin.com/jobs/search/?sortBy=R...  4.293203e+09
# 4        HI  https://www.linkedin.com/jobs/search/?sortBy=R...  4.294607e+09
# ...     ...                                                ...           ...
# 11131    MO  https://www.linkedin.com/jobs/search/?sortBy=R...  4.291961e+09
# 11132    MO  https://www.linkedin.com/jobs/search/?sortBy=R...  4.308498e+09
# 11133    MO  https://www.linkedin.com/jobs/search/?sortBy=R...  4.304439e+09
# 11134    MO  https://www.linkedin.com/jobs/search/?sortBy=R...  4.288327e+09
# 11135    MO  https://www.linkedin.com/jobs/search/?sortBy=R...  4.294224e+09
#
#                                                 job_name  \
# 0      Target Digital Network Analyst II - Utah Data ...
# 1      Society of Women Engineers WE25 Conference Att...
# 2                    Graduate Research Intern, Chemistry
# 3      Materials Engineering/Materials Science - Summ...
# 4      University, 2026 Summer Games Systems Engineer...
# ...                                                  ...
# 11131  Marketing/Communications Intern - Transmission...
# 11132                                    Data Analyst IV
# 11133  Paid Internship -- Software Development (Winte...
# 11134                         Junior Helpdesk Specialist
# 11135  Solutions Consulting & Engineering- MBA Manage...
#
#                             company_name                      job_location  \
# 0      Altamira Technologies Corporation             Wahiawa, HI (On-site)
# 1                                 Jacobs                      Honolulu, HI
# 2                         DataAnnotation    Hawaii, United States (Remote)
# 3                              Honeywell            United States (Remote)
# 4                    Booz Allen Hamilton             Honolulu, HI (Hybrid)
# ...                                  ...                               ...
# 11131                  Burns & McDonnell                   Kansas City, MO
# 11132                Centene Corporation  Missouri, United States (Remote)
# 11133                            Interco            St Louis, MO (On-site)
# 11134                   Chenega MIOS SBU            St Louis, MO (On-site)
# 11135              World Wide Technology    Maryland Heights, MO (On-site)
#
#                                                  job_url workplace_type  \
# 0      https://www.linkedin.com/jobs/view/4304560956/...        On-site
# 1      https://www.linkedin.com/jobs/view/4305161555/...        Unknown
# 2      https://www.linkedin.com/jobs/view/4304447345/...         Remote
# 3      https://www.linkedin.com/jobs/view/4293202567/...         Remote
# 4      https://www.linkedin.com/jobs/view/4294607020/...         Hybrid
# ...                                                  ...            ...
# 11131  https://www.linkedin.com/jobs/view/4291961454/...        Unknown
# 11132  https://www.linkedin.com/jobs/view/4308497710/...         Remote
# 11133  https://www.linkedin.com/jobs/view/4304439194/...        On-site
# 11134  https://www.linkedin.com/jobs/view/4288326603/...        On-site
# 11135  https://www.linkedin.com/jobs/view/4294223825/...        On-site
#
#                                          job_description Seniority level  \
# 0      Target Digital Network Analyst\nClearance: TS/...     Entry level
# 1      At Jacobs, we're challenging today to reinvent...  Not Applicable
# 2      Explore collaborative articles\n        \n\n\n...      Internship
# 3      Job Description\nThe future is what you make i...      Internship
# 4      Job Number: R0225531\nUniversity, 2026 Summer ...  Not Applicable
# ...                                                  ...             ...
# 11131  Description\nOur Engineering Interns are respo...  Not Applicable
# 11132  You could be the one who changes everything fo...  Not Applicable
# 11133  Company Description\nInterco is a global metal...      Internship
# 11134  Summary\nJunior Helpdesk Specialist \nSt. Loui...     Entry level
# 11135  About World Wide Technology\nAt World Wide Tec...      Internship
#
#       Employment type                                   Job function  \
# 0           Full-time                         Information Technology
# 1           Full-time         Engineering and Information Technology
# 2            Contract  Research, Analyst, and Information Technology
# 3           Full-time         Engineering and Information Technology
# 4          Internship                         Information Technology
# ...               ...                                            ...
# 11131       Full-time                            Marketing and Sales
# 11132       Full-time                         Information Technology
# 11133      Internship         Engineering and Information Technology
# 11134       Full-time                         Information Technology
# 11135       Full-time                 Sales and Business Development
#
#                                               Industries publish_time  \
# 0                                   Software Development   5 days ago
# 1      Civil Engineering, Design Services, and IT Ser...   1 week ago
# 2                                   Software Development  2 weeks ago
# 3      Appliances, Electrical, and Electronics Manufa...  2 weeks ago
# 4                          IT Services and IT Consulting   1 week ago
# ...                                                  ...          ...
# 11131                                       Construction  2 weeks ago
# 11132            Hospitals and Health Care and Insurance   1 week ago
# 11133       Renewable Energy Semiconductor Manufacturing  2 weeks ago
# 11134                    Defense and Space Manufacturing   6 days ago
# 11135                      IT Services and IT Consulting   1 week ago
#
#        num_applicants
# 0
# 1
# 2
# 3      142 applicants
# 4       58 applicants
# ...               ...
# 11131   47 applicants
# 11132   62 applicants
# 11133  189 applicants
# 11134   63 applicants
# 11135   86 applicants
#
# [11136 rows x 15 columns]

# %%
df_final.to_csv('data_center_jobs_enriched.csv', index=False)
