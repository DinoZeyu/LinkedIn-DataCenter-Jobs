# %%
import pandas as pd
import spacy
from spacy.matcher import PhraseMatcher
from pathlib import Path

# %%
GLOSSARY_XLSX = "Computer_science_glossary_terms.xlsx"             
TERM_COL      = "Computer Science Term"         
terms = pd.read_excel(GLOSSARY_XLSX, usecols=[TERM_COL])[TERM_COL].dropna().astype(str).tolist()

# %%
nlp = spacy.blank("en")                         

# We use Spacy Matcher to do Name Entity Recognition 
# Now we build the metcher pipeline
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
matcher.add("CS_TERMS", [nlp.make_doc(t) for t in terms])

def _to_text(x):
    if isinstance(x, list):
        return "\n".join(map(str, x))
    return "" if pd.isna(x) else str(x)

def extract_cs_terms(df: pd.DataFrame, cols, batch_size: int = 64):
    # Build one text per row by joining target columns
    texts = [
        "\n".join(_to_text(df.at[i, c]) for c in cols)
        for i in df.index
    ]

    out = []
    for doc in nlp.pipe(texts, batch_size=batch_size):
        found = {doc[s:e].text for _, s, e in matcher(doc)}
        out.append(sorted(found, key=lambda z: (z.lower(), len(z))))
    return pd.Series(out, index=df.index)

# %%
import pandas as pd

jobs = pd.read_csv("linkedin_data_center_jobs.csv")
cols_to_match = ['job_description']

jobs["cs glossary terms"] = extract_cs_terms(jobs, cols_to_match, batch_size=64)
jobs["cs glossary terms"] = jobs["cs glossary terms"].apply(lambda xs: " | ".join(xs))

# %%
jobs.head()
# Out:
#                                            job_title  \
# 0                         Imaging Student Intern PRN
# 1      DOD SkillBridge Internship – Field Technician
# 2      Geotechnical Engineering Intern - Summer 2026
# 3  Field Engineer Intern - Northwest District, He...
# 4                 Entry Level Engineers - Nationwide
#
#                company_name  Salary ($)  \
# 0  Alaska Regional Hospital         NaN
# 1                   Siemens         NaN
# 2           WSP in the U.S.         NaN
# 3                    Kiewit     46280.0
# 4                    Jacobs     72500.0
#
#                                      job_description num_applicants  \
# 0  DescriptionIntroductionDo you have the PRN car...            NaN
# 1  Here at Siemens, we take pride in enabling sus...            NaN
# 2  Job DescriptionThis OpportunityWSP USA hosts h...            NaN
# 3  Requisition ID:177228Job Level:InternshipHome ...  31 applicants
# 4  At Jacobs, we're challenging today to reinvent...            NaN
#
#                                              job_url   Seniority level  \
# 0  https://www.linkedin.com/jobs/view/4239122420/...        Internship
# 1  https://www.linkedin.com/jobs/view/4269469231/...  Mid-Senior level
# 2  https://www.linkedin.com/jobs/view/4286958078/...        Internship
# 3  https://www.linkedin.com/jobs/view/4287575140/...        Internship
# 4  https://www.linkedin.com/jobs/view/4305166349/...    Not Applicable
#
#   Employment type                            Job function  \
# 0       Part-time                    Health Care Provider
# 1       Full-time                                   Other
# 2      Internship  Engineering and Information Technology
# 3      Internship  Engineering and Information Technology
# 4       Full-time  Engineering and Information Technology
#
#                                           Industries workplace_type State  \
# 0                          Hospitals and Health Care        On-site    AK
# 1                 Automation Machinery Manufacturing        Unknown    AK
# 2                              Professional Services        On-site    AK
# 3                 Construction and Civil Engineering        On-site    AK
# 4  Civil Engineering, Design Services, and IT Ser...        Unknown    AK
#
#   publish_date       cs glossary terms
# 0     10/04/25
# 1     09/23/25           documentation
# 2     09/30/25  client | documentation
# 3     10/02/25
# 4     09/30/25    client | data center

# %%
jobs['cs glossary terms'].value_counts().head(20)
# Out:
# cs glossary terms
#                                                       3429
# client                                                 721
# documentation                                          690
# data center | Data Center                              397
# Python                                                 397
# data center                                            344
# client | documentation                                 218
# client | data center | Data Center                     218
# Data Center                                            195
# cloud computing | data center | Data Center            185
# client | data center                                   153
# database                                               123
# data center | Data Center | documentation               94
# documentation | Python                                  93
# client | data center | Data Center | documentation      80
# client | Data Center                                    78
# peripheral                                              71
# data center | documentation                             67
# client | Python                                         65
# Client | client                                         56
# Name: count, dtype: int64

# %%
jobs.to_csv("linkedIn_NER.csv", index=False)
